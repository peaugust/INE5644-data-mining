# %%
import pandas as pd
import seaborn as sns
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('max_rows', 200)
pd.set_option('display.max_colwidth', 150)

# %%
sellers = pd.read_csv('./data-2/olist_sellers_dataset.csv')

# %%
sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers.groupby('seller_state')['seller_state'].count().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_state, dtype: int64

# %%
ordered = sellers.groupby('seller_state')['seller_state'].count().reset_index(name='count').sort_values(['count'], ascending=False)
#sns.set_theme(style="white", palette=None)
#sns.set(rc = {'figure.figsize':(15,8)})
#sns.barplot(x=[1849, 349, 244, 190, 171], y=ordered['count'])


data = [1849, 349, 244, 190, 171, 171, 163]
labels = ['São Paulo','Paraná','Minas Gerais', 'Santa Catarina', 'Rio de Janeiro', 'Rio Grande do Sul', 'Demais estados']
plt.pie(data, labels = labels, autopct='%.0f%%')
plt.show()

# %%
filtered = costumers[costumers['customer_state'] == 'SP']
ordered = filtered.groupby('customer_city')['customer_city'].count().reset_index(name='count').sort_values(['count'], ascending=False)
selected=ordered.head()
sns.set(rc = {'figure.figsize':(14,7)})

sns.barplot(y=selected['customer_city'], x=selected['count'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='customer_city'>
