# %%
import pandas as pd
import seaborn as sns
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('max_rows', 200)
pd.set_option('display.max_colwidth', 150)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_11740/3709776131.py in <module>
# ----> 1 import pandas as pd
#       2 import seaborn as sns
#       3 import numpy as np
#       4 import pandas as pd
#       5 import missingno as msno
#
# ModuleNotFoundError: No module named 'pandas'

# %%
orders = pd.read_csv('./data-2/olist_orders_dataset.csv')
msno.matrix(orders.sample(99441)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
reviews = pd.read_csv('./data-2/olist_order_reviews_dataset.csv')
msno.matrix(reviews.sample(99224)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
payments = pd.read_csv('./data-2/olist_order_payments_dataset.csv')
msno.matrix(payments.sample(103886)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
items = pd.read_csv('./data-2/olist_order_items_dataset.csv')
msno.matrix(items.sample(112650)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
geolocation = pd.read_csv('./data-2/olist_geolocation_dataset.csv', dtype={'geolocation_zip_code_prefix': str})
msno.matrix(geolocation.sample(1000163)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
customers = pd.read_csv('./data-2/olist_customers_dataset.csv', dtype={'customer_zip_code_prefix': str})
msno.matrix(customers.sample(99441)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
# 
sns.countplot(x='review_score',data=reviews)
# Out:
# <AxesSubplot:xlabel='review_score', ylabel='count'>

# %%
sellers = pd.read_csv('./data-2/olist_sellers_dataset.csv', dtype={'customer_zip_code_prefix': str})
msno.matrix(sellers.sample(3095)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
payments = pd.read_csv('./data-2/olist_order_payments_dataset.csv')
msno.matrix(payments.sample(103886)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
products = pd.read_csv('./data-2/olist_products_dataset.csv')
msno.matrix(products.sample(32951)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
sns.histplot(reviews,x="review_score",binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='review_score', ylabel='Count'>

# %%
reviews.review_score.describe()
# Out:
# count    99224.000000
# mean         4.086421
# std          1.347579
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: review_score, dtype: float64

# %%
sns.countplot(x='customer_state',data=customers)
# Out:
# <AxesSubplot:xlabel='customer_state', ylabel='count'>

# %%
sns.countplot(x='seller_state',data=sellers)
# Out:
# <AxesSubplot:xlabel='seller_state', ylabel='count'>

# %%
# Out:
#               review_score
# review_score           1.0
