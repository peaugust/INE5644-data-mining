# %%
import pandas as pd
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport
from datetime import datetime

# %%
channels = pd.read_csv('./data-1/channels.csv')
channels
# Out:
#     channel_id    channel_name channel_type
# 0            1     OTHER PLACE  OWN CHANNEL
# 1            2     PHONE PLACE  OWN CHANNEL
# 2            3     WHATS PLACE  OWN CHANNEL
# 3            4      FACE PLACE  OWN CHANNEL
# 4            5      FOOD PLACE  MARKETPLACE
# 5            6     STORE PLACE  OWN CHANNEL
# 6            7    BERLIN PLACE  OWN CHANNEL
# 7            8    MADRID PLACE  OWN CHANNEL
# 8            9     THINK PLACE  OWN CHANNEL
# 9           10    LISBON PLACE  OWN CHANNEL
# 10          11     SUPER PLACE  OWN CHANNEL
# 11          12       ALL PLACE  MARKETPLACE
# 12          13  VELOCITY PLACE  MARKETPLACE
# 13          15      EATS PLACE  MARKETPLACE
# 14          17     SHOPP PLACE  MARKETPLACE
# 15          20    MUNICH PLACE  MARKETPLACE
# 16          21    LONDON PLACE  MARKETPLACE
# 17          23    ATCHIN PLACE  MARKETPLACE
# 18          24      FULL PLACE  MARKETPLACE
# 19          25        ON PLACE  MARKETPLACE
# ...

# %%
deliveries = pd.read_csv('./data-1/deliveries.csv')
deliveries
# Out:
#         delivery_id  delivery_order_id  driver_id  delivery_distance_meters  \
# 0           2174658           68413340     8378.0                    5199.0
# 1           2174660           68414309     2473.0                     410.0
# 2           2174661           68416230     7615.0                    3784.0
# 3           2174663           68412721     8378.0                    5714.0
# 4           2174675           68414018    10463.0                    3746.0
# ...             ...                ...        ...                       ...
# 378838      3134825           87083078     7615.0                    8110.0
# 378839      3135417           87660079    26223.0                   14454.0
# 378840      3135849           82340127    55429.0                    2546.0
# 378841      3142829           88586792    47016.0                    3106.0
# 378842      3144739           93026454    10504.0                    2919.0
#
#        delivery_status
# 0            DELIVERED
# ...

# %%
drivers = pd.read_csv('./data-1/drivers.csv')
drivers
# Out:
#       driver_id driver_modal        driver_type
# 0           133      MOTOBOY  LOGISTIC OPERATOR
# 1           138      MOTOBOY          FREELANCE
# 2           140      MOTOBOY          FREELANCE
# 3           143        BIKER          FREELANCE
# 4           148      MOTOBOY          FREELANCE
# ...         ...          ...                ...
# 4819      66260      MOTOBOY          FREELANCE
# 4820      66271        BIKER          FREELANCE
# 4821      66457      MOTOBOY  LOGISTIC OPERATOR
# 4822      66459      MOTOBOY  LOGISTIC OPERATOR
# 4823      66494      MOTOBOY          FREELANCE
#
# [4824 rows x 3 columns]

# %%
orders = pd.read_csv('./data-1/orders.csv')
orders
# Out:
#         order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 0       68405119      3512           5          68405119           68405119
# 1       68405123      3512           5          68405123           68405123
# 2       68405206      3512           5          68405206           68405206
# 3       68405465      3401           5          68405465           68405465
# 4       68406064      3401           5          68406064           68406064
# ...          ...       ...         ...               ...                ...
# 368994  93139806      2074           5          93139806           93139806
# 368995  93139809       707           5          93139809           93139809
# 368996  93139813       631           5          93139813           93139813
# 368997  93139814       631           5          93139814           93139814
# 368998  93139817       236           5          93139817           93139817
#
# ...

# %%
payments = pd.read_csv('./data-1/payments.csv')
payments
# Out:
#         payment_id  payment_order_id  payment_amount  payment_fee  \
# 0          4427917          68410055          118.44         0.00
# 1          4427918          68410055          394.81         7.90
# 2          4427941          68412721          206.95         5.59
# 3          4427948          68413340           58.80         1.59
# 4          4427955          68414018           45.80         0.92
# ...            ...               ...             ...          ...
# 400829     5535356          92271189           15.80         0.24
# 400830     5535359          90051751           93.30         1.87
# 400831     5536362          92645440           43.20         0.65
# 400832     5538634          92332079           59.90         0.90
# 400833     5540806          92889224           59.80         0.90
#
#               payment_method payment_status
# 0                    VOUCHER           PAID
# 1                     ONLINE           PAID
# ...

# %%
hubs = pd.read_csv('./data-1/hubs.csv')
hubs
# Out:
#     hub_id          hub_name        hub_city hub_state  hub_latitude  \
# 0        2     BLUE SHOPPING    PORTO ALEGRE        RS    -30.047415
# 1        3    GREEN SHOPPING    PORTO ALEGRE        RS    -30.037415
# 2        4      RED SHOPPING    PORTO ALEGRE        RS    -30.021948
# 3        5     FUNK SHOPPING  RIO DE JANEIRO        RJ    -23.000750
# 4        8   GOLDEN SHOPPING  RIO DE JANEIRO        RJ    -22.921475
# 5       13  HIP HOP SHOPPING  RIO DE JANEIRO        RJ    -22.885820
# 6       16   PEOPLE SHOPPING  RIO DE JANEIRO        RJ    -23.017472
# 7       17    SMALL SHOPPING       SAO PAULO        SP    -23.592004
# 8       18     STAR SHOPPING  RIO DE JANEIRO        RJ    -22.945495
# 9       20   PURPLE SHOPPING  RIO DE JANEIRO        RJ    -22.996848
# 10      21     WOLF SHOPPING       SAO PAULO        SP    -23.550407
# 11      22    COLOR SHOPPING  RIO DE JANEIRO        RJ    -23.000753
# 12      25   AVENUE SHOPPING       SAO PAULO        SP    -23.567703
# ...

# %%
stores = pd.read_csv('./data-1/stores.csv')
stores
# Out:
#      store_id  hub_id         store_name store_segment  store_plan_price  \
# 0           3       2            CUMIURI          FOOD               0.0
# 1           6       3  PIMGUCIS DA VIVA           FOOD               0.0
# 2           8       3          RASMUR S           FOOD               0.0
# 3          53       8        PAPA SUCIS           FOOD               0.0
# 4          54       8      VUZPI PAZZIS           FOOD               0.0
# ..        ...     ...                ...           ...               ...
# 946      4669      21           CIRUMOI           GOOD              29.0
# 947      4671      25           CIRUMOI           GOOD              49.9
# 948      4675      13       SIMUI LIMOI           GOOD              29.0
# 949      4676      75           PAMACIS           GOOD              49.9
# 950      4679      85      PIGUE PIPACO           FOOD              49.9
#
#      store_latitude  store_longitude
# 0               NaN              NaN
# ...

# %%
datasets = [channels, deliveries, drivers, orders, payments, hubs, stores]

print('Showing dataset infos')
for dataset in datasets:
    print(dataset.info())
    print('\n')
# Out:
# Showing dataset infos
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_id    40 non-null     int64
#  1   channel_name  40 non-null     object
#  2   channel_type  40 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378843 entries, 0 to 378842
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   delivery_id               378843 non-null  int64
#  1   delivery_order_id         378843 non-null  int64
#  2   driver_id                 362957 non-null  float64
#  3   delivery_distance_meters  378770 non-null  float64
#  4   delivery_status           378843 non-null  object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 14.5+ MB
# ...

# %%
print('Showing dataset heads')
for dataset in datasets:
    print(dataset.head(15))
    print('\n')
# Out:
# Showing dataset heads
#     channel_id    channel_name channel_type
# 0            1     OTHER PLACE  OWN CHANNEL
# 1            2     PHONE PLACE  OWN CHANNEL
# 2            3     WHATS PLACE  OWN CHANNEL
# 3            4      FACE PLACE  OWN CHANNEL
# 4            5      FOOD PLACE  MARKETPLACE
# 5            6     STORE PLACE  OWN CHANNEL
# 6            7    BERLIN PLACE  OWN CHANNEL
# 7            8    MADRID PLACE  OWN CHANNEL
# 8            9     THINK PLACE  OWN CHANNEL
# 9           10    LISBON PLACE  OWN CHANNEL
# 10          11     SUPER PLACE  OWN CHANNEL
# 11          12       ALL PLACE  MARKETPLACE
# 12          13  VELOCITY PLACE  MARKETPLACE
# 13          15      EATS PLACE  MARKETPLACE
# 14          17     SHOPP PLACE  MARKETPLACE
#
#
#     delivery_id  delivery_order_id  driver_id  delivery_distance_meters  \
# 0       2174658           68413340     8378.0                    5199.0
# 1       2174660           68414309     2473.0                     410.0
# ...

# %%
print('Showing dataset describe()')
for dataset in datasets:
    print(dataset.describe())
    print('\n')
# Out:
# Showing dataset describe()
#        channel_id
# count   40.000000
# mean    24.950000
# std     15.084293
# min      1.000000
# 25%     10.750000
# 50%     26.500000
# 75%     37.250000
# max     49.000000
#
#
#         delivery_id  delivery_order_id      driver_id  \
# count  3.788430e+05       3.788430e+05  362957.000000
# mean   2.634216e+06       8.220422e+07   21001.777643
# std    2.646553e+05       6.996909e+06   15520.652243
# min    2.174658e+06       6.840903e+07     133.000000
# 25%    2.405588e+06       7.631298e+07    7615.000000
# 50%    2.637111e+06       8.308321e+07   18754.000000
# 75%    2.860334e+06       8.787972e+07   31050.000000
# max    3.144739e+06       9.313982e+07   66459.000000
#
#        delivery_distance_meters
# count              3.787700e+05
# mean               1.072136e+04
# std                2.315392e+05
# min                0.000000e+00
# 25%                1.184000e+03
# 50%                2.073000e+03
# 75%                3.507000e+03
# ...

# %%
profile = ProfileReport(merged, title="Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-12-14 22:02:56.243327&quot;&gt;&lt;title&gt;Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
