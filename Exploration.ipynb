# %%
# import pandas as pd
import seaborn as sns
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('max_rows', 200)
pd.set_option('display.max_colwidth', 150)

#Datasets
orders = pd.read_csv('./data-2/olist_orders_dataset.csv')
reviews = pd.read_csv('./data-2/olist_order_reviews_dataset.csv')
payments = pd.read_csv('./data-2/olist_order_payments_dataset.csv')
items = pd.read_csv('./data-2/olist_order_items_dataset.csv')
geolocation = pd.read_csv('./data-2/olist_geolocation_dataset.csv', dtype={'geolocation_zip_code_prefix': str})
customers = pd.read_csv('./data-2/olist_customers_dataset.csv', dtype={'customer_zip_code_prefix': str})
sellers = pd.read_csv('./data-2/olist_sellers_dataset.csv', dtype={'customer_zip_code_prefix': str})
products = pd.read_csv('./data-2/olist_products_dataset.csv')

# %%
msno.matrix(orders.sample(orders.order_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(reviews.sample(reviews.review_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(payments.sample(payments.order_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(items.sample(items.order_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(geolocation.sample(1000163)) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(customers.sample(customers.customer_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(sellers.sample(sellers.seller_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(products.sample(products.product_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
msno.matrix(payments.sample(payments.order_id.count())) # Size of the dataset
# Out:
# <AxesSubplot:>

# %%
sns.histplot(reviews,x="review_score",binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='review_score', ylabel='Count'>

# %%
sns.countplot(x='customer_state',data=customers)
# Out:
# <AxesSubplot:xlabel='customer_state', ylabel='count'>

# %%
items_v2 = items.drop(columns=['order_item_id'])  
items_v2.describe()
# Out:
#                price  freight_value
# count  112650.000000  112650.000000
# mean      120.653739      19.990320
# std       183.633928      15.806405
# min         0.850000       0.000000
# 25%        39.900000      13.080000
# 50%        74.990000      16.260000
# 75%       134.900000      21.150000
# max      6735.000000     409.680000

# %%
reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# Quantidade de valores nulos por coluna em ORDERS
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# Quantidade de valores nulos por coluna em REVIEWS
reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# Quantidade de valores nulos por coluna em PRODUCTS
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# Quantidade de valores nulos por coluna em SELLERS
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
# Quantidade de valores nulos por coluna em CUSTOMERS
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
items.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
items.count()
